# %%
import mne
import matplotlib.pyplot as plt

# %%
raw = mne.io.read_raw_fif("data/poprawne.fif", preload=True)
try:
    raw.drop_channels(['contact_F3', 'contact_F4','contact_C3','contact_C4', 'contact_P3', 'contact_P4', 'contact_O1', 'contact_O2', 'Accel_x', 'Accel_y', 'Accel_z', 'Streaming', 'Battery'])
except :
    pass

# %%
print(raw.ch_names)
# Out:
# ['F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'Sample']

# %%
print(raw.info)
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: F3, F4, C3, C4, P3, P4, O1, O2, Sample
#  chs: 8 EEG, 1 misc
#  custom_ref_applied: False
#  dig: 11 items (3 Cardinal, 8 EEG)
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 9
#  projs: []
#  sfreq: 250.0 Hz
# >

# %%
cos = raw.get_data()

# %%
cos
# Out:
# array([[1.51916921e-01, 1.51924506e-01, 1.51926905e-01, ...,
#         1.65754303e-01, 1.65757522e-01, 1.65732116e-01],
#        [1.37938112e-01, 1.37944221e-01, 1.37944221e-01, ...,
#         1.46343157e-01, 1.46351993e-01, 1.46337718e-01],
#        [2.73033559e-01, 2.73032159e-01, 2.73052543e-01, ...,
#         2.61352748e-01, 2.61343688e-01, 2.61356026e-01],
#        ...,
#        [1.43451065e-01, 1.43462330e-01, 1.43469557e-01, ...,
#         1.58594489e-01, 1.58595279e-01, 1.58564374e-01],
#        [1.65955335e-01, 1.65966675e-01, 1.65970162e-01, ...,
#         1.86088935e-01, 1.86089203e-01, 1.86065391e-01],
#        [5.06400000e+03, 5.06500000e+03, 5.06600000e+03, ...,
#         1.76990000e+04, 1.77000000e+04, 1.76800000e+04]], shape=(9, 25253))

# %%
time = cos[8]
val = cos[1]

# %%
plt.plot(val)
plt.show()

# %%
raw.plot_psd(tmin=0, tmax=60, fmin=2, fmax=60, average=True, spatial_colors=False)
# Out:
# /home/szymon/BrainGradient/venv/lib/python3.12/site-packages/mne/viz/utils.py:160: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
raw.notch_filter(50,)
# 2 Hz to 42 Hz
raw.filter(2, 42)
# Out:
# <Raw | poprawne.fif, 9 x 25253 (101.0 s), ~1.8 MiB, data loaded>

# %%
raw.plot_psd(tmin=0, tmax=60, fmin=2, fmax=60, average=True, spatial_colors=False)
# Out:
# /home/szymon/BrainGradient/venv/lib/python3.12/site-packages/mne/viz/utils.py:160: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
fig = raw.plot(scalings='auto', show=False)
fig.set_size_inches(15, 10)
plt.show()
# Out:
# <MNEBrowseFigure size 1500x1000 with 4 Axes>
